# %%
# string, text data type

'this is a string'
# Out:
# 'this is a string'

# %%
"this is also a string"
# Out:
# 'this is also a string'

# %%
'Let's see if this works
# Out:
#   Cell In[5], line 1
#     'Let's see if this works
#          ^
# SyntaxError: invalid syntax

# %%
'This is not a valid string"
# Out:
#   Cell In[6], line 1
#     'This is not a valid string"
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"Let's see if this is a string"
# Out:
# "Let's see if this is a string"

# %%
'''This
 is
   a
     multiline
       string

'''

# the \n in the output is an escape sequence
# that indicates that we have gone to a new line
# Out:
# 'This\n is\n   a\n     multiline\n       string\n\n'

# %%
'Let\'s see if this works'
# Out:
# "Let's see if this works"

# %%
"How do backslashes \\ work"
# Out:
# 'How do backslashes \\ work'

# %%
"Can I make a single\\backslash"
# Out:
# 'Can I make a single\\backslash'

# %%
"single \\backslash"
# Out:
# 'single \\backslash'

# %%
"single \\backslash"
# Out:
# 'single \\backslash'

# %%
print ("This is a \ttab")
# Out:
# This is a 	tab

# %%
"This is a \ttab"
# Out:
# 'This is a \ttab'

# %%
# \r moves the cursor back to the beginning of the current line

print('1234\r567')
# Out:
# 5674

# %%
10+3
# Out:
# 13

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
10 + 3
# Out:
# 13

# %%
10 + 3
10 / 3
# Out:
# 3.3333333333333335

# %%
'the year is' + ' 2020'
# Out:
# 'the year is 2020'

# %%
print('abcdef\r g ')
# Out:
#  g def

# %%
apple = 3

# %%
apple
# Out:
# 3

# %%
Apple = apple

# %%
Apple
# Out:
# 3

# %%
apple = apple + 3

# %%
Apple
# Out:
# 3

# %%
apple
# Out:
# 6

# %%
Apple
# Out:
# 3

# %%
Apple = apple

# %%
Apple
# Out:
# 3

# %%
apple
# Out:
# 3

# %%
del apple , Apple
